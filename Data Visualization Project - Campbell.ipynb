# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')

# %%
college_crimes = pd.read_csv("https://raw.githubusercontent.com/LorenzoPizza/CollegeCrimes2019/main/project_dataset.csv")
college_crimes.ffill(axis = 0)
# Out:
#          State       University/College          Campus  \
# 0       ALASKA     University of Alaska:      Anchorage
# 1       ALASKA     University of Alaska:      Fairbanks
# 2      ARIZONA  Arizona State University    Main Campus
# 3      ARIZONA   Arizona Western College    Main Campus
# 4      ARIZONA   Central Arizona College    Main Campus
# ..         ...                       ...            ...
# 563  WISCONSIN  University of Wisconsin:    River Falls
# 564  WISCONSIN  University of Wisconsin:  Stevens Point
# 565  WISCONSIN  University of Wisconsin:       Superior
# 566  WISCONSIN  University of Wisconsin:     Whitewater
# 567    WYOMING     University of Wyoming     Whitewater
#
#     Student\r\nenrollment1  Violent\r\ncrime  \
# 0                   24,144                 1
# 1                   12,738                 3
# 2                  127,582                49
# 3                   11,492                 0
# 4                    8,086                 0
# ...
